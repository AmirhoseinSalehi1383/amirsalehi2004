# %%
x = [1, 3]
y = [3, 7]
sum = 0
for i in range(2):
    sum += x[i] + y[i]
result1 = (sum* 2) / 100
print("نتیجه مرحله اول =", result1)
value1 = result1 * (x[0] + y[0])
value2 = result1 * (x[1] + y[1])
total = value1 + value2
final = total / 100
print("نتیجه نهایی =", final)
#با کمی کمک از chat gbt
# Out:
# نتیجه مرحله اول = 0.28
# نتیجه نهایی = 0.039200000000000006
